# %%
import os
import csv
import pandas as pd

# %%
path = "/NIA50/50-2/data/하자데이터/폴더오류/폴더구조오류"
file_list01 = os.listdir(path)
file_list01
# Out:
# ['L_2210_Suwon_B_N_C0061',
#  'L_2210_Suwon_B_N_C0001',
#  'L_2210_Suwon_B_N_C0022',
#  'L_2210_Suwon_B_N_C0065',
#  'L_2210_Suwon_B_N_C0014',
#  'L_2210_Suwon_B_N_C0037',
#  'L_2210_Suwon_B_N_C0053',
#  'L_2210_Suwon_B_N_C0019',
#  'L_2210_Suwon_B_N_C0042',
#  'L_2210_Suwon_B_N_C0003',
#  'L_2210_Suwon_B_N_C0005',
#  'L_2210_Suwon_B_N_C0062',
#  'L_2210_Suwon_B_N_C0058',
#  'L_2210_Suwon_B_N_C0008',
#  'L_2210_Suwon_B_N_C0167',
#  'L_2210_Suwon_B_A_C0043',
#  'L_2210_Suwon_B_N_C0020',
#  'L_2210_Suwon_B_N_C0006',
#  'L_2210_Suwon_B_N_C0029',
#  'L_2210_Suwon_B_N_C0057',
#  'L_2210_Suwon_B_N_C0025',
#  'L_2210_Suwon_B_N_C0166',
#  'L_2210_Suwon_B_N_C0048',
#  'L_2210_Suwon_B_N_C0066',
#  'L_2210_Suwon_B_N_C0010',
#  'L_2210_Suwon_B_N_C0046',
#  'L_2210_Suwon_B_N_C0017',
#  'L_2210_Suwon_B_N_C0051',
#  'L_2210_Suwon_B_N_C0018',
#  'L_2210_Suwon_B_N_C0007',
#  'L_2210_Suwon_B_N_C0041',
#  'L_2210_Suwon_B_N_C0013',
#  'L_2210_Suwon_B_N_C0052',
#  'L_2210_Suwon_B_N_C0031',
# ...

# %%
with open('filelist00','w') as file :

    write = csv.writer(file)
    write.writerow(file_list00)

# %%
df01 = pd.DataFrame(file_list01, columns=['file_name'])
df01
# Out:
#                  file_name
# 0   L_2210_Suwon_B_N_C0061
# 1   L_2210_Suwon_B_N_C0001
# 2   L_2210_Suwon_B_N_C0022
# 3   L_2210_Suwon_B_N_C0065
# 4   L_2210_Suwon_B_N_C0014
# ..                     ...
# 73  L_2210_Suwon_B_N_C0043
# 74  L_2210_Suwon_B_N_C0004
# 75  L_2210_Suwon_B_N_C0023
# 76  L_2210_Suwon_A_N_C0034
# 77  L_2210_Suwon_B_N_C0027
#
# [78 rows x 1 columns]

# %%
df01.to_csv('폴더구조오류.csv', sep=',')
