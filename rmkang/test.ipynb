# %%
import os

os.system("unzip /data/NIA50/50-2/Suwon2.zip")
# Out:
# Archive:  /data/NIA50/50-2/Suwon2.zip
#   inflating: Suwon_B_0000.zip
#   inflating: Suwon_B_0001.zip
#   inflating: Suwon_B_0002.zip
#   inflating: Suwon_B_0003.zip
#   inflating: Suwon_B_0004.zip
#   inflating: Suwon_B_0005.zip
# 0

# %%
from scipy.spatial.transform import Rotation as R
