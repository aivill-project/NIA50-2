# %% [markdown]
# # # DeepfusionMOT 설치
# ---

# %%
# DeepfusionMOT 설치

# %cd /content/drive/MyDrive/workspace/study/3D_Object_detection
# !git clone https://github.com/wangxiyang2022/DeepFusionMOT

# %%
# 필요 모듈 설치

# %cd /data/NIA50/50-2/models/DeepFusionMOT
# !pip install -r requirements.txt

# %% [markdown]
# # # MOT 실행
# ---
# - CUDA_VISIBLE_DEVICES=3 pm2 start main.py --interpreter python --name "deepfusionmot_integ_test" --no-autorestart -- --data-root /data/NIA50/50-2/data/nia50_final/deepfusionmot_integ --detections3D 3D_pvrcnn --detections2D 2D_yolov5 --save-root /data/NIA50/50-2/result/deepfusionmot_integ --save-img

# %%
# 디텍팅
# main.py와 visualization에서 경로 수정 필수

# %cd /data/NIA50/50-2/models/DeepFusionMOT
# !python main.py

# %%
# %cd /data/NIA50/50-2/models/DeepFusionMOT_aivill

data_root = '/data/NIA50/50-2/data/nia50_final/deepfusionmot_integ_2'
detections_3D = '3D_pvrcnn'
detections_2D = '2D_yolov5'
save_root = '/data/NIA50/50-2/result/deepfusionmot_integ_2'

# !python main.py --data-root {data_root} --detections3D {detections_3D} --detections2D {detections_2D} --save-root {save_root} --save-img
# Out:
# /data/NIA50/50-2/models/DeepFusionMOT_aivill
# --------------Start processing the L_2210_Suwon_A_N_C0198 dataset--------------
# --------------The time it takes to process all datasets are 5.319467306137085s --------------
# --------------Start processing the L_2210_Suwon_A_N_C0199 dataset--------------
# --------------The time it takes to process all datasets are 5.826221704483032s --------------
# --------------Start processing the L_2210_Suwon_A_N_C0378 dataset--------------
# --------------The time it takes to process all datasets are 6.293829679489136s --------------
# --------------Start processing the L_2210_Suwon_A_N_C0379 dataset--------------
# --------------The time it takes to process all datasets are 6.422673940658569s --------------
# --------------Start processing the L_2210_Suwon_A_N_C0380 dataset--------------
# --------------The time it takes to process all datasets are 6.4896533489227295s --------------
# --------------Start processing the L_2210_Suwon_A_N_C0382 dataset--------------
# --------------The time it takes to process all datasets are 6.524315595626831s --------------
# --------------Start processing the L_2210_Suwon_A_N_C0383 dataset--------------
# --------------The time it takes to process all datasets are 6.645020008087158s --------------
# --------------Start processing the L_2210_Suwon_A_N_C0384 dataset--------------
# --------------The time it takes to process all datasets are 6.736059665679932s --------------
# --------------Start processing the L_2210_Suwon_A_N_C0385 dataset--------------
# --------------The time it takes to process all datasets are 6.987593412399292s --------------
# --------------Start processing the L_2210_Suwon_A_N_C0386 dataset--------------
# --------------The time it takes to process all datasets are 7.237408876419067s --------------
# --------------Start processing the L_2210_Suwon_A_N_C0387 dataset--------------
# --------------The time it takes to process all datasets are 7.5308263301849365s --------------
# --------------Start processing the L_2210_Suwon_A_N_C0388 dataset--------------
# --------------The time it takes to process all datasets are 7.771218299865723s --------------
# --------------Start processing the L_2210_Suwon_A_N_C0389 dataset--------------
# --------------The time it takes to process all datasets are 8.121167182922363s --------------
# --------------Start processing the L_2210_Suwon_A_N_C0390 dataset--------------
# --------------The time it takes to process all datasets are 8.552872896194458s --------------
# --------------Start processing the L_2210_Suwon_A_N_C0391 dataset--------------
# --------------The time it takes to process all datasets are 9.110600233078003s --------------
# --------------Start processing the L_2210_Suwon_A_N_C0392 dataset--------------
# --------------The time it takes to process all datasets are 9.595118522644043s --------------
# --------------Start processing the L_2210_Suwon_A_N_C0393 dataset--------------
# --------------The time it takes to process all datasets are 10.38111686706543s --------------
# --------------Start processing the L_2210_Suwon_A_N_C0394 dataset--------------
# --------------The time it takes to process all datasets are 11.312967777252197s --------------
# --------------Start processing the L_2210_Suwon_A_N_C0395 dataset--------------
# --------------The time it takes to process all datasets are 11.827067852020264s --------------
# --------------Start processing the L_2210_Suwon_A_N_C0396 dataset--------------
# --------------The time it takes to process all datasets are 12.433232307434082s --------------
# --------------Start processing the L_2210_Suwon_A_N_C0397 dataset--------------
# --------------The time it takes to process all datasets are 12.66512155532837s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0362 dataset--------------
# --------------The time it takes to process all datasets are 13.068727254867554s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0363 dataset--------------
# --------------The time it takes to process all datasets are 13.460672616958618s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0364 dataset--------------
# --------------The time it takes to process all datasets are 13.911154985427856s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0365 dataset--------------
# --------------The time it takes to process all datasets are 14.121101140975952s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0366 dataset--------------
# --------------The time it takes to process all datasets are 14.432240962982178s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0367 dataset--------------
# --------------The time it takes to process all datasets are 14.8869309425354s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0368 dataset--------------
# --------------The time it takes to process all datasets are 15.19614577293396s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0369 dataset--------------
# --------------The time it takes to process all datasets are 15.484257698059082s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0370 dataset--------------
# --------------The time it takes to process all datasets are 15.946406602859497s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0371 dataset--------------
# --------------The time it takes to process all datasets are 16.296070098876953s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0372 dataset--------------
# --------------The time it takes to process all datasets are 16.76136088371277s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0373 dataset--------------
# --------------The time it takes to process all datasets are 17.357513666152954s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0374 dataset--------------
# --------------The time it takes to process all datasets are 18.05379867553711s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0375 dataset--------------
# --------------The time it takes to process all datasets are 18.647664308547974s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0376 dataset--------------
# --------------The time it takes to process all datasets are 19.17792797088623s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0377 dataset--------------
# --------------The time it takes to process all datasets are 19.681792974472046s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0378 dataset--------------
# --------------The time it takes to process all datasets are 20.17221713066101s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0379 dataset--------------
# --------------The time it takes to process all datasets are 20.57625937461853s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0380 dataset--------------
# --------------The time it takes to process all datasets are 20.89441418647766s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0381 dataset--------------
# --------------The time it takes to process all datasets are 21.193556785583496s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0382 dataset--------------
# --------------The time it takes to process all datasets are 21.477651596069336s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0383 dataset--------------
# --------------The time it takes to process all datasets are 21.7949481010437s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0384 dataset--------------
# --------------The time it takes to process all datasets are 22.13734793663025s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0385 dataset--------------
# --------------The time it takes to process all datasets are 22.67883539199829s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0386 dataset--------------
# --------------The time it takes to process all datasets are 23.116747856140137s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0387 dataset--------------
# --------------The time it takes to process all datasets are 23.641374111175537s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0388 dataset--------------
# --------------The time it takes to process all datasets are 23.919482469558716s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0389 dataset--------------
# --------------The time it takes to process all datasets are 24.294446229934692s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0390 dataset--------------
# --------------The time it takes to process all datasets are 24.639211654663086s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0391 dataset--------------
# --------------The time it takes to process all datasets are 25.07924795150757s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0392 dataset--------------
# --------------The time it takes to process all datasets are 25.524235010147095s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0393 dataset--------------
# --------------The time it takes to process all datasets are 26.14130425453186s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0394 dataset--------------
# --------------The time it takes to process all datasets are 26.77371621131897s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0395 dataset--------------
# --------------The time it takes to process all datasets are 27.55581545829773s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0396 dataset--------------
# --------------The time it takes to process all datasets are 28.103747367858887s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0397 dataset--------------
# --------------The time it takes to process all datasets are 28.48167586326599s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0398 dataset--------------
# --------------The time it takes to process all datasets are 28.698978662490845s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0399 dataset--------------
# --------------The time it takes to process all datasets are 28.861237287521362s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0400 dataset--------------
# --------------The time it takes to process all datasets are 29.05162811279297s --------------
# --------------Start processing the L_2211_Pangyo_C_A_C0266 dataset--------------
# --------------The time it takes to process all datasets are 29.294718027114868s --------------
# --------------Start processing the L_2211_Pangyo_C_A_C0267 dataset--------------
# --------------The time it takes to process all datasets are 29.453525066375732s --------------
# --------------Start processing the L_2211_Pangyo_C_A_C0268 dataset--------------
# --------------The time it takes to process all datasets are 29.6294207572937s --------------
# --------------Start processing the L_2211_Pangyo_C_A_C0269 dataset--------------
# --------------The time it takes to process all datasets are 29.919768571853638s --------------
# --------------Start processing the L_2211_Pangyo_C_A_C0270 dataset--------------
# --------------The time it takes to process all datasets are 30.157673120498657s --------------
# --------------Start processing the L_2211_Pangyo_C_A_C0271 dataset--------------
# --------------The time it takes to process all datasets are 30.38265633583069s --------------
# --------------Start processing the L_2211_Pangyo_C_A_C0272 dataset--------------
# --------------The time it takes to process all datasets are 30.51410150527954s --------------
# --------------Start processing the L_2211_Pangyo_C_A_C0273 dataset--------------
# --------------The time it takes to process all datasets are 30.636380672454834s --------------
# --------------Start processing the L_2211_Pangyo_C_A_C0274 dataset--------------
# --------------The time it takes to process all datasets are 30.81727910041809s --------------
# --------------Start processing the L_2211_Pangyo_C_A_C0275 dataset--------------
# --------------The time it takes to process all datasets are 31.130823850631714s --------------
# --------------Start processing the L_2211_Pangyo_C_A_C0276 dataset--------------
# --------------The time it takes to process all datasets are 31.54541826248169s --------------
# --------------Start processing the L_2211_Pangyo_C_A_C0277 dataset--------------
# --------------The time it takes to process all datasets are 32.07738924026489s --------------
# --------------Start processing the L_2211_Pangyo_C_A_C0284 dataset--------------
# --------------The time it takes to process all datasets are 32.35873341560364s --------------
# --------------Start processing the L_2211_Pangyo_C_A_C0285 dataset--------------
# --------------The time it takes to process all datasets are 32.78071451187134s --------------
# --------------Start processing the L_2211_Pangyo_C_A_C0286 dataset--------------
# --------------The time it takes to process all datasets are 33.231218338012695s --------------
# --------------Start processing the L_2211_Pangyo_C_A_C0287 dataset--------------
# --------------The time it takes to process all datasets are 33.53178095817566s --------------
# --------------Start processing the L_2211_Pangyo_C_A_C0288 dataset--------------
# --------------The time it takes to process all datasets are 33.940526485443115s --------------
# --------------Start processing the L_2211_Pangyo_C_A_C0289 dataset--------------
# --------------The time it takes to process all datasets are 34.492995262145996s --------------
# --------------Start processing the L_2211_Pangyo_C_A_C0290 dataset--------------
# --------------The time it takes to process all datasets are 35.100974321365356s --------------
# --------------Start processing the L_2211_Pangyo_C_A_C0291 dataset--------------
# --------------The time it takes to process all datasets are 35.67681312561035s --------------
# --------------Start processing the L_2211_Pangyo_C_A_C0296 dataset--------------
# --------------The time it takes to process all datasets are 36.45390462875366s --------------
# --------------Start processing the L_2211_Pangyo_C_A_C0297 dataset--------------
# --------------The time it takes to process all datasets are 37.186135053634644s --------------
# --------------Start processing the L_2211_Pangyo_C_A_C0298 dataset--------------
# --------------The time it takes to process all datasets are 38.06461524963379s --------------
# --------------Start processing the L_2211_Pangyo_C_A_C0299 dataset--------------
# --------------The time it takes to process all datasets are 38.83609342575073s --------------
# --------------Start processing the L_2211_Pangyo_C_A_C0300 dataset--------------
# --------------The time it takes to process all datasets are 39.510905742645264s --------------
# --------------Start processing the L_2211_Pangyo_C_A_C0301 dataset--------------
# --------------The time it takes to process all datasets are 40.28505611419678s --------------
# --------------Start processing the L_2211_Pangyo_C_D_C0127 dataset--------------
# --------------The time it takes to process all datasets are 40.99108815193176s --------------
# --------------Start processing the L_2211_Pangyo_C_D_C0128 dataset--------------
# --------------The time it takes to process all datasets are 41.750853538513184s --------------
# --------------Start processing the L_2211_Pangyo_C_D_C0129 dataset--------------
# --------------The time it takes to process all datasets are 42.396199226379395s --------------
# --------------Start processing the L_2211_Pangyo_C_F_C0916 dataset--------------
# --------------The time it takes to process all datasets are 43.237056255340576s --------------
# --------------Start processing the L_2211_Pangyo_C_F_C0917 dataset--------------
# --------------The time it takes to process all datasets are 44.22480535507202s --------------
# --------------Start processing the L_2211_Pangyo_C_F_C0918 dataset--------------
# --------------The time it takes to process all datasets are 45.64763116836548s --------------
# --------------Start processing the L_2211_Pangyo_C_F_C0919 dataset--------------
# --------------The time it takes to process all datasets are 46.747843503952026s --------------
# --------------Start processing the L_2211_Pangyo_C_F_C0920 dataset--------------
# --------------The time it takes to process all datasets are 47.367767333984375s --------------
# --------------Start processing the L_2211_Pangyo_C_F_C0921 dataset--------------
# --------------The time it takes to process all datasets are 47.79305410385132s --------------
# --------------Start processing the L_2211_Pangyo_C_F_C0922 dataset--------------
# --------------The time it takes to process all datasets are 48.037992000579834s --------------
# --------------Start processing the L_2211_Pangyo_C_F_C0923 dataset--------------
# --------------The time it takes to process all datasets are 48.285768270492554s --------------
# --------------Start processing the L_2211_Pangyo_C_F_C0924 dataset--------------
# --------------The time it takes to process all datasets are 48.53828263282776s --------------
# --------------Start processing the L_2211_Pangyo_C_F_C0925 dataset--------------
# --------------The time it takes to process all datasets are 49.032726526260376s --------------
# --------------Start processing the L_2211_Pangyo_C_F_C0926 dataset--------------
# --------------The time it takes to process all datasets are 49.467580795288086s --------------
# --------------Start processing the L_2211_Pangyo_C_F_C0927 dataset--------------
# --------------The time it takes to process all datasets are 49.69351840019226s --------------
# --------------Start processing the L_2211_Pangyo_C_F_C0928 dataset--------------
# --------------The time it takes to process all datasets are 50.06524395942688s --------------
# --------------Start processing the L_2211_Pangyo_C_F_C0929 dataset--------------
# --------------The time it takes to process all datasets are 50.43538784980774s --------------
# --------------Start processing the L_2211_Pangyo_C_F_C0930 dataset--------------
# --------------The time it takes to process all datasets are 50.69788193702698s --------------
# --------------Start processing the L_2211_Pangyo_C_F_C0931 dataset--------------
# --------------The time it takes to process all datasets are 50.96179127693176s --------------
# --------------Start processing the L_2211_Pangyo_C_F_C0932 dataset--------------
# --------------The time it takes to process all datasets are 51.2014102935791s --------------
# --------------Start processing the L_2211_Pangyo_C_F_C0933 dataset--------------
# --------------The time it takes to process all datasets are 51.36060166358948s --------------
# --------------Start processing the L_2211_Pangyo_C_F_C0934 dataset--------------
# --------------The time it takes to process all datasets are 51.52578353881836s --------------
# --------------Start processing the L_2211_Pangyo_C_F_C0935 dataset--------------
# --------------The time it takes to process all datasets are 51.70309805870056s --------------
# --------------Start processing the L_2211_Pangyo_C_F_C0936 dataset--------------
# --------------The time it takes to process all datasets are 52.20052742958069s --------------
# --------------Start processing the L_2211_Pangyo_C_F_C0937 dataset--------------
# --------------The time it takes to process all datasets are 52.81129193305969s --------------
# --------------Start processing the L_2211_Pangyo_C_F_C0938 dataset--------------
# --------------The time it takes to process all datasets are 53.48239016532898s --------------
# --------------Start processing the L_2211_Pangyo_C_F_C0939 dataset--------------
# --------------The time it takes to process all datasets are 54.181443214416504s --------------
# --------------Start processing the L_2211_Pangyo_C_F_C0940 dataset--------------
# --------------The time it takes to process all datasets are 55.16436576843262s --------------
# --------------Start processing the L_2211_Pangyo_C_F_C0941 dataset--------------
# --------------The time it takes to process all datasets are 55.70647692680359s --------------
# --------------Start processing the L_2211_Pangyo_C_F_C0942 dataset--------------
# --------------The time it takes to process all datasets are 56.27547907829285s --------------
# --------------Start processing the L_2211_Pangyo_C_F_C0943 dataset--------------
# --------------The time it takes to process all datasets are 56.6985878944397s --------------
# --------------Start processing the L_2211_Pangyo_C_F_C0944 dataset--------------
# --------------The time it takes to process all datasets are 57.219223737716675s --------------
# --------------Start processing the L_2211_Pangyo_C_F_C0945 dataset--------------
# --------------The time it takes to process all datasets are 57.66182470321655s --------------
# --------------Start processing the L_2211_Pangyo_C_F_C0946 dataset--------------
# --------------The time it takes to process all datasets are 57.977396965026855s --------------
# --------------Start processing the L_2211_Pangyo_C_F_C0949 dataset--------------
# --------------The time it takes to process all datasets are 58.43898367881775s --------------
# --------------Start processing the L_2211_Pangyo_C_F_C0950 dataset--------------
# --------------The time it takes to process all datasets are 58.99278116226196s --------------
# --------------Start processing the L_2211_Pangyo_C_F_C0951 dataset--------------
# --------------The time it takes to process all datasets are 59.40853810310364s --------------
# --------------Start processing the L_2211_Pangyo_C_F_C0952 dataset--------------
# --------------The time it takes to process all datasets are 59.8102970123291s --------------
# --------------Start processing the L_2211_Pangyo_C_F_C0953 dataset--------------
# --------------The time it takes to process all datasets are 60.42318320274353s --------------
# --------------Start processing the L_2211_Pangyo_C_F_C0954 dataset--------------
# --------------The time it takes to process all datasets are 60.86993980407715s --------------
# --------------Start processing the L_2211_Pangyo_C_F_C0955 dataset--------------
# --------------The time it takes to process all datasets are 61.40623760223389s --------------
# --------------Start processing the L_2211_Pangyo_C_F_C0956 dataset--------------
# --------------The time it takes to process all datasets are 61.93697476387024s --------------
# --------------Start processing the L_2211_Pangyo_C_F_C0957 dataset--------------
# --------------The time it takes to process all datasets are 62.58769965171814s --------------
# --------------Start processing the L_2211_Pangyo_C_F_C0958 dataset--------------
# --------------The time it takes to process all datasets are 63.45914387702942s --------------
# --------------Start processing the L_2211_Pangyo_C_F_C0959 dataset--------------
# --------------The time it takes to process all datasets are 64.35805106163025s --------------
# --------------Start processing the L_2211_Pangyo_C_F_C0960 dataset--------------
# --------------The time it takes to process all datasets are 65.15020418167114s --------------
# --------------Start processing the L_2211_Pangyo_C_F_C0961 dataset--------------
# --------------The time it takes to process all datasets are 65.83311200141907s --------------
# --------------Start processing the L_2211_Pangyo_C_F_C0962 dataset--------------
# --------------The time it takes to process all datasets are 66.25543856620789s --------------
# --------------Start processing the L_2211_Pangyo_C_F_C0963 dataset--------------
# --------------The time it takes to process all datasets are 66.85709977149963s --------------
# --------------Start processing the L_2211_Pangyo_D_A_C0271 dataset--------------
# --------------The time it takes to process all datasets are 68.09471988677979s --------------
# --------------Start processing the L_2211_Pangyo_D_A_C0272 dataset--------------
# --------------The time it takes to process all datasets are 69.03797960281372s --------------
# --------------Start processing the L_2211_Pangyo_D_A_C0273 dataset--------------
# --------------The time it takes to process all datasets are 70.47470569610596s --------------
# --------------Start processing the L_2211_Pangyo_D_A_C0274 dataset--------------
# --------------The time it takes to process all datasets are 72.36069345474243s --------------
# --------------Start processing the L_2211_Pangyo_D_A_C0275 dataset--------------
# --------------The time it takes to process all datasets are 74.36359143257141s --------------
# --------------Start processing the L_2211_Pangyo_D_A_C0276 dataset--------------
# --------------The time it takes to process all datasets are 76.64587879180908s --------------
# --------------Start processing the L_2211_Pangyo_D_A_C0277 dataset--------------
# --------------The time it takes to process all datasets are 79.44399785995483s --------------
# --------------Start processing the L_2211_Pangyo_D_A_C0278 dataset--------------
# --------------The time it takes to process all datasets are 81.57555389404297s --------------
# --------------Start processing the L_2211_Pangyo_D_A_C0279 dataset--------------
# --------------The time it takes to process all datasets are 83.19432187080383s --------------
# --------------Start processing the L_2211_Pangyo_D_A_C0280 dataset--------------
# --------------The time it takes to process all datasets are 84.71111273765564s --------------
# --------------Start processing the L_2211_Pangyo_D_A_C0281 dataset--------------
# --------------The time it takes to process all datasets are 86.26078271865845s --------------
# --------------Start processing the L_2211_Pangyo_D_A_C0282 dataset--------------
# --------------The time it takes to process all datasets are 87.44154739379883s --------------
# --------------Start processing the L_2211_Pangyo_D_A_C0283 dataset--------------
# --------------The time it takes to process all datasets are 88.72753238677979s --------------
# --------------Start processing the L_2211_Pangyo_D_A_C0284 dataset--------------
# --------------The time it takes to process all datasets are 89.64450693130493s --------------
# --------------Start processing the L_2211_Pangyo_D_A_C0285 dataset--------------
# --------------The time it takes to process all datasets are 90.60725927352905s --------------
# --------------Start processing the L_2211_Pangyo_D_A_C0286 dataset--------------
# --------------The time it takes to process all datasets are 91.4634735584259s --------------
# --------------Start processing the L_2211_Pangyo_D_A_C0287 dataset--------------
# --------------The time it takes to process all datasets are 92.28398537635803s --------------
# --------------Start processing the L_2211_Pangyo_D_A_C0288 dataset--------------
# --------------The time it takes to process all datasets are 93.01314926147461s --------------
# --------------Start processing the L_2211_Pangyo_D_A_C0289 dataset--------------
# --------------The time it takes to process all datasets are 93.89959049224854s --------------
# --------------Start processing the L_2211_Pangyo_D_A_C0290 dataset--------------
# --------------The time it takes to process all datasets are 94.59650802612305s --------------
# --------------Start processing the L_2211_Pangyo_D_A_C0291 dataset--------------
# --------------The time it takes to process all datasets are 95.46413540840149s --------------
# --------------Start processing the L_2211_Pangyo_D_A_C0292 dataset--------------
# --------------The time it takes to process all datasets are 96.15425276756287s --------------
# --------------Start processing the L_2211_Pangyo_D_A_C0293 dataset--------------
# --------------The time it takes to process all datasets are 96.68733596801758s --------------
# --------------Start processing the L_2211_Pangyo_D_A_C0294 dataset--------------
# --------------The time it takes to process all datasets are 97.49065637588501s --------------
# --------------Start processing the L_2211_Pangyo_D_A_C0295 dataset--------------
# --------------The time it takes to process all datasets are 98.72273421287537s --------------
# --------------Start processing the L_2211_Pangyo_D_A_C0296 dataset--------------
# --------------The time it takes to process all datasets are 100.07324504852295s --------------
# --------------Start processing the L_2211_Pangyo_D_A_C0297 dataset--------------
# --------------The time it takes to process all datasets are 101.58293604850769s --------------
# --------------Start processing the L_2211_Pangyo_D_A_C0298 dataset--------------
# --------------The time it takes to process all datasets are 102.98924326896667s --------------
# --------------Start processing the L_2211_Pangyo_D_A_C0299 dataset--------------
# --------------The time it takes to process all datasets are 104.06453561782837s --------------
# --------------Start processing the L_2211_Pangyo_D_A_C0300 dataset--------------
# --------------The time it takes to process all datasets are 105.12109303474426s --------------
# --------------Start processing the L_2211_Pangyo_D_D_C0133 dataset--------------
# --------------The time it takes to process all datasets are 105.81444072723389s --------------
# --------------Start processing the L_2211_Pangyo_D_D_C0148 dataset--------------
# --------------The time it takes to process all datasets are 106.36349105834961s --------------
# --------------Start processing the L_2211_Pangyo_D_D_C0149 dataset--------------
# --------------The time it takes to process all datasets are 106.78260231018066s --------------
# --------------Start processing the L_2211_Pangyo_D_D_C0150 dataset--------------
# --------------The time it takes to process all datasets are 107.23543691635132s --------------
# --------------Start processing the L_2211_Pangyo_D_D_C0151 dataset--------------
# --------------The time it takes to process all datasets are 107.71796989440918s --------------
# --------------Start processing the L_2211_Pangyo_D_F_C0433 dataset--------------
# --------------The time it takes to process all datasets are 108.2589693069458s --------------
# --------------Start processing the L_2211_Pangyo_D_F_C0434 dataset--------------
# --------------The time it takes to process all datasets are 108.88417220115662s --------------
# --------------Start processing the L_2211_Pangyo_D_F_C0435 dataset--------------
# --------------The time it takes to process all datasets are 109.40580248832703s --------------
# --------------Start processing the L_2211_Pangyo_D_F_C0436 dataset--------------
# --------------The time it takes to process all datasets are 109.87108087539673s --------------
# --------------Start processing the L_2211_Pangyo_D_F_C0437 dataset--------------
# --------------The time it takes to process all datasets are 110.55025863647461s --------------
# --------------Start processing the L_2211_Pangyo_D_F_C0438 dataset--------------
# --------------The time it takes to process all datasets are 110.99280428886414s --------------
# --------------Start processing the L_2211_Pangyo_D_F_C0439 dataset--------------
# --------------The time it takes to process all datasets are 111.3016300201416s --------------
# --------------Start processing the L_2211_Pangyo_D_F_C0440 dataset--------------
# --------------The time it takes to process all datasets are 111.81559109687805s --------------
# --------------Start processing the L_2211_Pangyo_D_F_C0441 dataset--------------
# --------------The time it takes to process all datasets are 112.14554166793823s --------------
# --------------Start processing the L_2211_Pangyo_D_F_C0442 dataset--------------
# --------------The time it takes to process all datasets are 112.57662606239319s --------------
# --------------Start processing the L_2211_Pangyo_D_F_C0443 dataset--------------
# --------------The time it takes to process all datasets are 112.94202828407288s --------------
# --------------Start processing the L_2211_Pangyo_D_F_C0444 dataset--------------
# --------------The time it takes to process all datasets are 113.27781224250793s --------------
# --------------Start processing the L_2211_Pangyo_D_F_C0445 dataset--------------
# --------------The time it takes to process all datasets are 113.53475594520569s --------------
# --------------Start processing the L_2211_Pangyo_D_F_C0446 dataset--------------
# --------------The time it takes to process all datasets are 114.17229557037354s --------------
# --------------Start processing the L_2211_Pangyo_D_F_C0447 dataset--------------
# --------------The time it takes to process all datasets are 114.72428011894226s --------------
# --------------Start processing the L_2211_Pangyo_D_F_C0448 dataset--------------
# --------------The time it takes to process all datasets are 115.29776358604431s --------------
# --------------Start processing the L_2211_Pangyo_D_F_C0449 dataset--------------
# --------------The time it takes to process all datasets are 115.7699875831604s --------------
# --------------Start processing the L_2211_Pangyo_D_F_C0450 dataset--------------
# --------------The time it takes to process all datasets are 116.37405323982239s --------------
# --------------Start processing the L_2211_Pangyo_D_F_C0451 dataset--------------
# --------------The time it takes to process all datasets are 117.07556533813477s --------------
# --------------Start processing the L_2211_Pangyo_D_F_C0452 dataset--------------
# --------------The time it takes to process all datasets are 117.84992504119873s --------------
# --------------Start processing the L_2211_Pangyo_D_F_C0453 dataset--------------
# --------------The time it takes to process all datasets are 118.51210355758667s --------------
# --------------Start processing the L_2211_Pangyo_D_F_C0454 dataset--------------
# --------------The time it takes to process all datasets are 119.26974129676819s --------------
# --------------Start processing the L_2211_Pangyo_D_F_C0455 dataset--------------
# --------------The time it takes to process all datasets are 120.05084252357483s --------------
# --------------Start processing the L_2211_Pangyo_D_F_C0456 dataset--------------
# --------------The time it takes to process all datasets are 120.8118839263916s --------------
# --------------Start processing the L_2211_Pangyo_D_F_C0457 dataset--------------
# --------------The time it takes to process all datasets are 121.44764924049377s --------------
# --------------Start processing the L_2211_Pangyo_D_F_C0458 dataset--------------
# --------------The time it takes to process all datasets are 122.25213623046875s --------------
# --------------Start processing the L_2211_Pangyo_D_F_C0459 dataset--------------
# --------------The time it takes to process all datasets are 122.68958234786987s --------------
# --------------Start processing the L_2211_Pangyo_D_F_C0460 dataset--------------
# --------------The time it takes to process all datasets are 123.21359610557556s --------------
# --------------Start processing the L_2211_Pangyo_D_F_C0461 dataset--------------
# --------------The time it takes to process all datasets are 123.67846512794495s --------------
# --------------Start processing the L_2211_Pangyo_D_F_C0462 dataset--------------
# --------------The time it takes to process all datasets are 124.32405352592468s --------------
# --------------Start processing the L_2211_Pangyo_D_F_C0463 dataset--------------
# --------------The time it takes to process all datasets are 124.97276091575623s --------------
# --------------Start processing the L_2211_Pangyo_D_F_C0464 dataset--------------
# --------------The time it takes to process all datasets are 125.46052527427673s --------------
# --------------Start processing the L_2211_Pangyo_D_F_C0465 dataset--------------
# --------------The time it takes to process all datasets are 126.0212950706482s --------------
# --------------Start processing the L_2211_Pangyo_D_F_C0466 dataset--------------
# --------------The time it takes to process all datasets are 126.61874341964722s --------------
# --------------Start processing the L_2211_Pangyo_D_F_C0467 dataset--------------
# --------------The time it takes to process all datasets are 127.5099892616272s --------------
# --------------Start processing the L_2211_Pangyo_D_F_C0468 dataset--------------
# --------------The time it takes to process all datasets are 128.21566462516785s --------------
# --------------Start processing the L_2211_Pangyo_D_F_C0469 dataset--------------
# --------------The time it takes to process all datasets are 128.8254873752594s --------------
# --------------Start processing the L_2211_Pangyo_D_F_C0470 dataset--------------
# --------------The time it takes to process all datasets are 129.30350422859192s --------------
# --------------Start processing the L_2211_Pangyo_D_F_C0471 dataset--------------
# --------------The time it takes to process all datasets are 129.8324956893921s --------------
# --------------Start processing the L_2211_Pangyo_D_F_C0472 dataset--------------
# --------------The time it takes to process all datasets are 130.50519061088562s --------------
# --------------Start processing the L_2211_Pangyo_D_F_C0473 dataset--------------
# --------------The time it takes to process all datasets are 131.127911567688s --------------
# --------------Start processing the L_2211_Pangyo_D_F_C0474 dataset--------------
# --------------The time it takes to process all datasets are 131.73867177963257s --------------
# --------------Start processing the L_2211_Pangyo_D_F_C0475 dataset--------------
# --------------The time it takes to process all datasets are 132.45336437225342s --------------
# --------------Start processing the L_2211_Pangyo_D_F_C0476 dataset--------------
# --------------The time it takes to process all datasets are 133.08455848693848s --------------
# --------------Start processing the L_2211_Pangyo_D_F_C0477 dataset--------------
# --------------The time it takes to process all datasets are 133.729257106781s --------------
# --------------Start processing the L_2211_Pangyo_D_F_C0478 dataset--------------
# --------------The time it takes to process all datasets are 134.34506464004517s --------------
# --------------Start processing the L_2211_Pangyo_D_F_C0479 dataset--------------
# --------------The time it takes to process all datasets are 134.94114708900452s --------------
# --------------Start processing the L_2211_Suwon_A_A_C0556 dataset--------------
# --------------The time it takes to process all datasets are 136.11683416366577s --------------
# --------------Start processing the L_2211_Suwon_A_A_C0557 dataset--------------
# --------------The time it takes to process all datasets are 137.15008544921875s --------------
# --------------Start processing the L_2211_Suwon_A_A_C0558 dataset--------------
# --------------The time it takes to process all datasets are 138.1155138015747s --------------
# --------------Start processing the L_2211_Suwon_A_A_C0559 dataset--------------
# --------------The time it takes to process all datasets are 139.58597612380981s --------------
# --------------Start processing the L_2211_Suwon_A_A_C0560 dataset--------------
# --------------The time it takes to process all datasets are 140.6717209815979s --------------
# --------------Start processing the L_2211_Suwon_A_A_C0561 dataset--------------
# --------------The time it takes to process all datasets are 141.65609884262085s --------------
# --------------Start processing the L_2211_Suwon_A_A_C0562 dataset--------------
# --------------The time it takes to process all datasets are 142.643625497818s --------------
# --------------Start processing the L_2211_Suwon_A_A_C0563 dataset--------------
# --------------The time it takes to process all datasets are 143.79411387443542s --------------
# --------------Start processing the L_2211_Suwon_A_A_C0564 dataset--------------
# --------------The time it takes to process all datasets are 144.84539699554443s --------------
# --------------Start processing the L_2211_Suwon_A_A_C0565 dataset--------------
# --------------The time it takes to process all datasets are 145.71409511566162s --------------
# --------------Start processing the L_2211_Suwon_A_A_C0566 dataset--------------
# --------------The time it takes to process all datasets are 146.56743001937866s --------------
# --------------Start processing the L_2211_Suwon_A_A_C0567 dataset--------------
# --------------The time it takes to process all datasets are 147.16305375099182s --------------
# --------------Start processing the L_2211_Suwon_A_A_C0568 dataset--------------
# --------------The time it takes to process all datasets are 147.73309016227722s --------------
# --------------Start processing the L_2211_Suwon_A_A_C0569 dataset--------------
# --------------The time it takes to process all datasets are 148.88464307785034s --------------
# --------------Start processing the L_2211_Suwon_A_A_C0570 dataset--------------
# --------------The time it takes to process all datasets are 150.24311709403992s --------------
# --------------Start processing the L_2211_Suwon_A_A_C0571 dataset--------------
# --------------The time it takes to process all datasets are 151.85839319229126s --------------
# --------------Start processing the L_2211_Suwon_A_A_C0572 dataset--------------
# --------------The time it takes to process all datasets are 153.15526700019836s --------------
# --------------Start processing the L_2211_Suwon_A_A_C0573 dataset--------------
# --------------The time it takes to process all datasets are 154.21494102478027s --------------
# --------------Start processing the L_2211_Suwon_A_A_C0574 dataset--------------
# --------------The time it takes to process all datasets are 155.35121083259583s --------------
# --------------Start processing the L_2211_Suwon_A_A_C0575 dataset--------------
# --------------The time it takes to process all datasets are 156.47853183746338s --------------
# --------------Start processing the L_2211_Suwon_A_A_C0576 dataset--------------
# --------------The time it takes to process all datasets are 157.5296664237976s --------------
# --------------Start processing the L_2211_Suwon_A_A_C0577 dataset--------------
# --------------The time it takes to process all datasets are 158.37202906608582s --------------
# --------------Start processing the L_2211_Suwon_A_A_C0578 dataset--------------
# --------------The time it takes to process all datasets are 159.23905968666077s --------------
# --------------Start processing the L_2211_Suwon_A_A_C0579 dataset--------------
# --------------The time it takes to process all datasets are 160.3504605293274s --------------
# --------------Start processing the L_2211_Suwon_A_A_C0580 dataset--------------
# --------------The time it takes to process all datasets are 161.2902159690857s --------------
# --------------Start processing the L_2211_Suwon_A_A_C0581 dataset--------------
# --------------The time it takes to process all datasets are 162.41132283210754s --------------
# --------------Start processing the L_2211_Suwon_A_A_C0582 dataset--------------
# --------------The time it takes to process all datasets are 163.19518327713013s --------------
# --------------Start processing the L_2211_Suwon_A_A_C0583 dataset--------------
# --------------The time it takes to process all datasets are 163.9301414489746s --------------
# --------------Start processing the L_2211_Suwon_A_A_C0584 dataset--------------
# --------------The time it takes to process all datasets are 164.76760268211365s --------------
# --------------Start processing the L_2211_Suwon_A_A_C0585 dataset--------------
# --------------The time it takes to process all datasets are 166.00177931785583s --------------
# --------------Start processing the L_2211_Suwon_A_A_C0586 dataset--------------
# --------------The time it takes to process all datasets are 166.9289698600769s --------------
# --------------Start processing the L_2211_Suwon_A_A_C0587 dataset--------------
# --------------The time it takes to process all datasets are 168.15475225448608s --------------
# --------------Start processing the L_2211_Suwon_A_A_C0588 dataset--------------
# --------------The time it takes to process all datasets are 169.11971473693848s --------------
# --------------Start processing the L_2211_Suwon_A_A_C0589 dataset--------------
# --------------The time it takes to process all datasets are 169.95302295684814s --------------
# --------------Start processing the L_2211_Suwon_A_A_C0590 dataset--------------
# --------------The time it takes to process all datasets are 170.73736834526062s --------------
# --------------Start processing the L_2211_Suwon_A_A_C0591 dataset--------------
# --------------The time it takes to process all datasets are 171.9175944328308s --------------
# --------------Start processing the L_2211_Suwon_A_A_C0592 dataset--------------
# --------------The time it takes to process all datasets are 172.7139458656311s --------------
# --------------Start processing the L_2211_Suwon_A_A_C0593 dataset--------------
# --------------The time it takes to process all datasets are 173.53171467781067s --------------
# --------------Start processing the L_2211_Suwon_A_A_C0594 dataset--------------
# --------------The time it takes to process all datasets are 174.46665596961975s --------------
# --------------Start processing the L_2211_Suwon_A_A_C0595 dataset--------------
# --------------The time it takes to process all datasets are 175.04508924484253s --------------
# --------------Start processing the L_2211_Suwon_A_A_C0596 dataset--------------
# --------------The time it takes to process all datasets are 175.87011885643005s --------------
# --------------Start processing the L_2211_Suwon_A_A_C0597 dataset--------------
# --------------The time it takes to process all datasets are 176.76375532150269s --------------
# --------------Start processing the L_2211_Suwon_A_A_C0598 dataset--------------
# --------------The time it takes to process all datasets are 177.45923042297363s --------------
# --------------Start processing the L_2211_Suwon_A_A_C0599 dataset--------------
# --------------The time it takes to process all datasets are 178.22920680046082s --------------
# --------------Start processing the L_2211_Suwon_A_A_C0600 dataset--------------
# --------------The time it takes to process all datasets are 179.016827583313s --------------
# --------------Start processing the L_2211_Suwon_A_A_C0601 dataset--------------
# --------------The time it takes to process all datasets are 179.98826432228088s --------------
# --------------Start processing the L_2211_Suwon_A_A_C0602 dataset--------------
# --------------The time it takes to process all datasets are 181.4103922843933s --------------
# --------------Start processing the L_2211_Suwon_A_A_C0603 dataset--------------
# --------------The time it takes to process all datasets are 182.76342630386353s --------------
# --------------Start processing the L_2211_Suwon_A_A_C0604 dataset--------------
# --------------The time it takes to process all datasets are 184.10832619667053s --------------
# --------------Start processing the L_2211_Suwon_A_A_C0605 dataset--------------
# --------------The time it takes to process all datasets are 185.0525825023651s --------------
# --------------Start processing the L_2211_Suwon_A_A_C0606 dataset--------------
# --------------The time it takes to process all datasets are 185.78549528121948s --------------
# --------------Start processing the L_2211_Suwon_A_A_C0607 dataset--------------
# --------------The time it takes to process all datasets are 186.7168254852295s --------------
# --------------Start processing the L_2211_Suwon_A_A_C0608 dataset--------------
# --------------The time it takes to process all datasets are 187.62986063957214s --------------
# --------------Start processing the L_2211_Suwon_A_A_C0609 dataset--------------
# --------------The time it takes to process all datasets are 188.71442794799805s --------------
# --------------Start processing the L_2211_Suwon_A_A_C0610 dataset--------------
# --------------The time it takes to process all datasets are 189.6461808681488s --------------
# --------------Start processing the L_2211_Suwon_A_A_C0611 dataset--------------
# --------------The time it takes to process all datasets are 190.5877981185913s --------------
# --------------Start processing the L_2211_Suwon_A_A_C0612 dataset--------------
# ...
# --------------Start processing the L_2211_Suwon_B_A_C0785 dataset--------------
# --------------The time it takes to process all datasets are 235.5052695274353s --------------
# --------------Start processing the L_2211_Suwon_B_A_C0786 dataset--------------
# --------------The time it takes to process all datasets are 235.61979961395264s --------------
# --------------Start processing the L_2211_Suwon_B_A_C0787 dataset--------------
# --------------The time it takes to process all datasets are 235.74019813537598s --------------
# --------------Start processing the L_2211_Suwon_B_A_C0788 dataset--------------
# --------------The time it takes to process all datasets are 235.95671010017395s --------------
# --------------Start processing the L_2211_Suwon_B_A_C0789 dataset--------------
# --------------The time it takes to process all datasets are 236.15634846687317s --------------
# --------------Start processing the L_2211_Suwon_B_A_C0790 dataset--------------
# --------------The time it takes to process all datasets are 236.36562871932983s --------------
# --------------Start processing the L_2211_Suwon_B_A_C0791 dataset--------------
# --------------The time it takes to process all datasets are 236.5437672138214s --------------
# --------------Start processing the L_2211_Suwon_B_A_C0792 dataset--------------
# --------------The time it takes to process all datasets are 236.7319176197052s --------------
# --------------Start processing the L_2211_Suwon_B_A_C0793 dataset--------------
# --------------The time it takes to process all datasets are 236.967613697052s --------------
# --------------Start processing the L_2211_Suwon_B_A_C0794 dataset--------------
# --------------The time it takes to process all datasets are 237.1644217967987s --------------
# --------------Start processing the L_2211_Suwon_B_A_C0795 dataset--------------
# --------------The time it takes to process all datasets are 237.3314507007599s --------------
# --------------Start processing the L_2211_Suwon_B_A_C0796 dataset--------------
# --------------The time it takes to process all datasets are 237.4842448234558s --------------
# --------------Start processing the L_2211_Suwon_B_A_C0797 dataset--------------
# --------------The time it takes to process all datasets are 237.65816855430603s --------------
# --------------Start processing the L_2211_Suwon_B_A_C0798 dataset--------------
# --------------The time it takes to process all datasets are 237.8641402721405s --------------
# --------------Start processing the L_2211_Suwon_B_A_C0799 dataset--------------
# --------------The time it takes to process all datasets are 238.07549667358398s --------------
# --------------Start processing the L_2211_Suwon_B_A_C0800 dataset--------------
# --------------The time it takes to process all datasets are 238.26965808868408s --------------
# --------------Start processing the L_2211_Suwon_B_D_C0136 dataset--------------
# --------------The time it takes to process all datasets are 238.64004492759705s --------------
# --------------Start processing the L_2211_Suwon_B_D_C0137 dataset--------------
# --------------The time it takes to process all datasets are 239.0446047782898s --------------
# --------------Start processing the L_2211_Suwon_B_D_C0138 dataset--------------
# --------------The time it takes to process all datasets are 239.342467546463s --------------
# --------------Start processing the L_2211_Suwon_B_D_C0139 dataset--------------
# --------------The time it takes to process all datasets are 239.4997787475586s --------------
# --------------Start processing the L_2211_Suwon_B_D_C0140 dataset--------------
# --------------The time it takes to process all datasets are 239.59295654296875s --------------
# --------------Start processing the L_2211_Suwon_B_D_C0141 dataset--------------
# --------------The time it takes to process all datasets are 239.71208238601685s --------------
# --------------Start processing the L_2211_Suwon_B_D_C0142 dataset--------------
# --------------The time it takes to process all datasets are 239.85137224197388s --------------
# --------------Start processing the L_2211_Suwon_B_D_C0143 dataset--------------
# --------------The time it takes to process all datasets are 239.98745584487915s --------------
# --------------Start processing the L_2211_Suwon_B_D_C0144 dataset--------------
# --------------The time it takes to process all datasets are 240.1136772632599s --------------
# --------------Start processing the L_2211_Suwon_B_D_C0145 dataset--------------
# --------------The time it takes to process all datasets are 240.27326774597168s --------------
# --------------Start processing the L_2211_Suwon_B_D_C0146 dataset--------------
# --------------The time it takes to process all datasets are 240.48799228668213s --------------
# --------------Start processing the L_2211_Suwon_B_D_C0147 dataset--------------
# --------------The time it takes to process all datasets are 240.76762533187866s --------------
# --------------Start processing the L_2211_Suwon_B_D_C0148 dataset--------------
# --------------The time it takes to process all datasets are 241.13027143478394s --------------
# --------------Start processing the L_2211_Suwon_B_D_C0149 dataset--------------
# --------------The time it takes to process all datasets are 241.48336386680603s --------------
# --------------Start processing the L_2211_Suwon_B_D_C0150 dataset--------------
# --------------The time it takes to process all datasets are 241.79498744010925s --------------
# --------------Start processing the L_2211_Suwon_B_D_C0151 dataset--------------
# --------------The time it takes to process all datasets are 242.24881219863892s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0859 dataset--------------
# --------------The time it takes to process all datasets are 242.7377188205719s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0860 dataset--------------
# --------------The time it takes to process all datasets are 243.09385919570923s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0861 dataset--------------
# --------------The time it takes to process all datasets are 243.43182396888733s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0875 dataset--------------
# --------------The time it takes to process all datasets are 244.23655080795288s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0876 dataset--------------
# --------------The time it takes to process all datasets are 245.02758288383484s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0877 dataset--------------
# --------------The time it takes to process all datasets are 245.6324257850647s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0878 dataset--------------
# --------------The time it takes to process all datasets are 246.11288595199585s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0879 dataset--------------
# --------------The time it takes to process all datasets are 246.5999984741211s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0880 dataset--------------
# --------------The time it takes to process all datasets are 247.0851662158966s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0881 dataset--------------
# --------------The time it takes to process all datasets are 247.50042462348938s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0882 dataset--------------
# --------------The time it takes to process all datasets are 247.9447672367096s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0883 dataset--------------
# --------------The time it takes to process all datasets are 248.3581771850586s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0884 dataset--------------
# --------------The time it takes to process all datasets are 248.77067685127258s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0885 dataset--------------
# --------------The time it takes to process all datasets are 249.0881040096283s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0886 dataset--------------
# --------------The time it takes to process all datasets are 249.42533159255981s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0887 dataset--------------
# --------------The time it takes to process all datasets are 249.9171645641327s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0888 dataset--------------
# --------------The time it takes to process all datasets are 250.49471497535706s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0892 dataset--------------
# --------------The time it takes to process all datasets are 251.07611274719238s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0893 dataset--------------
# --------------The time it takes to process all datasets are 251.48952960968018s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0894 dataset--------------
# --------------The time it takes to process all datasets are 252.09745383262634s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0895 dataset--------------
# --------------The time it takes to process all datasets are 252.5527708530426s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0896 dataset--------------
# --------------The time it takes to process all datasets are 252.99064898490906s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0924 dataset--------------
# --------------The time it takes to process all datasets are 253.37159705162048s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0925 dataset--------------
# --------------The time it takes to process all datasets are 253.694678068161s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0926 dataset--------------
# --------------The time it takes to process all datasets are 253.90600156784058s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0927 dataset--------------
# --------------The time it takes to process all datasets are 254.1172022819519s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0929 dataset--------------
# --------------The time it takes to process all datasets are 254.32473850250244s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0930 dataset--------------
# --------------The time it takes to process all datasets are 254.87382054328918s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0931 dataset--------------
# --------------The time it takes to process all datasets are 255.4313657283783s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0939 dataset--------------
# --------------The time it takes to process all datasets are 256.39309525489807s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0940 dataset--------------
# --------------The time it takes to process all datasets are 257.16455125808716s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0941 dataset--------------
# --------------The time it takes to process all datasets are 257.9326877593994s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0942 dataset--------------
# --------------The time it takes to process all datasets are 258.75847697257996s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0943 dataset--------------
# --------------The time it takes to process all datasets are 259.36738443374634s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0948 dataset--------------
# --------------The time it takes to process all datasets are 260.34357476234436s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0955 dataset--------------
# --------------The time it takes to process all datasets are 261.35338306427s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0956 dataset--------------
# --------------The time it takes to process all datasets are 262.291170835495s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0957 dataset--------------
# --------------The time it takes to process all datasets are 263.173353433609s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0958 dataset--------------
# --------------The time it takes to process all datasets are 263.9278452396393s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0959 dataset--------------
# --------------The time it takes to process all datasets are 264.7180082798004s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0960 dataset--------------
# --------------The time it takes to process all datasets are 265.4245843887329s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0964 dataset--------------
# --------------The time it takes to process all datasets are 266.19839334487915s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0965 dataset--------------
# --------------The time it takes to process all datasets are 266.84857201576233s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0966 dataset--------------
# --------------The time it takes to process all datasets are 267.4624936580658s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0967 dataset--------------
# --------------The time it takes to process all datasets are 268.1063597202301s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0968 dataset--------------
# --------------The time it takes to process all datasets are 268.8414738178253s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0989 dataset--------------
# --------------The time it takes to process all datasets are 269.36945843696594s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0990 dataset--------------
# --------------The time it takes to process all datasets are 269.7869300842285s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0991 dataset--------------
# --------------The time it takes to process all datasets are 270.4267621040344s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0992 dataset--------------
# --------------The time it takes to process all datasets are 271.10249972343445s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0993 dataset--------------
# --------------The time it takes to process all datasets are 271.6352345943451s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0994 dataset--------------
# --------------The time it takes to process all datasets are 272.3442351818085s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0995 dataset--------------
# --------------The time it takes to process all datasets are 272.9089126586914s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0996 dataset--------------
# --------------The time it takes to process all datasets are 273.8109540939331s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0997 dataset--------------
# --------------The time it takes to process all datasets are 274.87599515914917s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0998 dataset--------------
# --------------The time it takes to process all datasets are 275.9135534763336s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0999 dataset--------------
# --------------The time it takes to process all datasets are 276.6879172325134s --------------
# --------------Start processing the L_2211_Suwon_B_F_C1000 dataset--------------
# --------------The time it takes to process all datasets are 277.2403392791748s --------------
# --------------Start processing the L_2211_Suwon_B_F_C1001 dataset--------------
# --------------The time it takes to process all datasets are 277.86125087738037s --------------
# --------------FPS = 17.06247267306874 --------------

# %%
# %cd /NIA50/50-2/models/DeepFusionMOT

# !python main.py --help

# %% [markdown]
# # # 결과물 영상화
# ---

# %%
# 디텍팅 결과 영상 생성
# img_to_video.py 수정 필수

# %cd /content/drive/MyDrive/workspace/study/3D_Object_detection/DeepFusionMOT/visualization
# !python img_to_video.py
