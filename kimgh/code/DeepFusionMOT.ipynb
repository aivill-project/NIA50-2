# %% [markdown]
# # # DeepfusionMOT 설치
# ---

# %%
# DeepfusionMOT 설치

# %cd /content/drive/MyDrive/workspace/study/3D_Object_detection
# !git clone https://github.com/wangxiyang2022/DeepFusionMOT

# %%
# 필요 모듈 설치

# %cd /data/NIA50/50-2/models/DeepFusionMOT
# !pip install -r requirements.txt

# %% [markdown]
# # # MOT 실행
# ---

# %%
# 디텍팅
# main.py와 visualization에서 경로 수정 필수

# %cd /data/NIA50/50-2/models/DeepFusionMOT
# !python main.py
# Out:
# /data/NIA50/50-2/models/DeepFusionMOT
# --------------Start processing the Suwon_A_2210261635_0000 dataset--------------
# /data/NIA50/50-2/models/DeepFusionMOT/tracking/cost_function.py:32: NumbaPerformanceWarning: np.dot() is faster on contiguous arrays, called on (array(float64, 1d, A), array(float64, 1d, C))
#   return 0.5 * np.abs(np.dot(x, np.roll(y, 1)) - np.dot(y, np.roll(x, 1)))
# --------------The time it takes to process all datasets are 1.4121978282928467s --------------
# --------------Start processing the Suwon_A_2210261635_0039 dataset--------------
# --------------The time it takes to process all datasets are 1.8855276107788086s --------------
# --------------Start processing the Suwon_A_2210261635_0062 dataset--------------
# --------------The time it takes to process all datasets are 2.473790168762207s --------------
# --------------Start processing the Suwon_A_2210261635_0069 dataset--------------
# --------------The time it takes to process all datasets are 2.9072790145874023s --------------
# --------------Start processing the Suwon_A_2210261635_0101 dataset--------------
# --------------The time it takes to process all datasets are 3.2001025676727295s --------------
# --------------Start processing the Suwon_A_2210261635_0102 dataset--------------
# ^C
# Traceback (most recent call last):
#   File "/data/NIA50/50-2/models/DeepFusionMOT/main.py", line 160, in <module>
#     img_0 = cv2.imread(img0_path)
# KeyboardInterrupt

# %%
# %cd /data/NIA50/50-2/models/DeepFusionMOT_aivill

data_root = '/data/NIA50/50-2/data/NIA50/nia50_all/deepfusionmot_allcat'
detections_3D = '3D_pvrcnn'
detections_2D = '2D_yolov5'
save_root = '/data/NIA50/50-2/result/deepfusionmot_allcat'

# !python main.py --data-root {data_root} --detections3D {detections_3D} --detections2D {detections_2D} --save-root {save_root} --save-img
# Out:
# /NIA50/50-2/models/DeepFusionMOT
# --------------Start processing the L_2210_Suwon_A_A_C0004 dataset--------------
# /NIA50/50-2/models/DeepFusionMOT/tracking/cost_function.py:32: NumbaPerformanceWarning: np.dot() is faster on contiguous arrays, called on (array(float64, 1d, A), array(float64, 1d, C))
#   return 0.5 * np.abs(np.dot(x, np.roll(y, 1)) - np.dot(y, np.roll(x, 1)))
# --------------The time it takes to process all datasets are 1.2039096355438232s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0006 dataset--------------
# --------------The time it takes to process all datasets are 1.585155963897705s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0020 dataset--------------
# --------------The time it takes to process all datasets are 2.069063663482666s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0021 dataset--------------
# --------------The time it takes to process all datasets are 2.556410551071167s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0036 dataset--------------
# --------------The time it takes to process all datasets are 3.0379698276519775s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0038 dataset--------------
# --------------The time it takes to process all datasets are 3.5318915843963623s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0040 dataset--------------
# --------------The time it takes to process all datasets are 4.158918857574463s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0047 dataset--------------
# --------------The time it takes to process all datasets are 4.499991416931152s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0048 dataset--------------
# --------------The time it takes to process all datasets are 4.756640911102295s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0051 dataset--------------
# --------------The time it takes to process all datasets are 5.042844772338867s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0054 dataset--------------
# --------------The time it takes to process all datasets are 5.453146934509277s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0065 dataset--------------
# --------------The time it takes to process all datasets are 5.7493510246276855s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0067 dataset--------------
# --------------The time it takes to process all datasets are 6.062908887863159s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0069 dataset--------------
# --------------The time it takes to process all datasets are 6.357768297195435s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0072 dataset--------------
# --------------The time it takes to process all datasets are 6.902466058731079s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0075 dataset--------------
# --------------The time it takes to process all datasets are 7.364129304885864s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0079 dataset--------------
# --------------The time it takes to process all datasets are 7.835721015930176s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0081 dataset--------------
# --------------The time it takes to process all datasets are 8.434727430343628s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0082 dataset--------------
# --------------The time it takes to process all datasets are 8.931882619857788s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0084 dataset--------------
# --------------The time it takes to process all datasets are 9.266218900680542s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0089 dataset--------------
# --------------The time it takes to process all datasets are 9.84836721420288s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0101 dataset--------------
# --------------The time it takes to process all datasets are 10.251913785934448s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0115 dataset--------------
# --------------The time it takes to process all datasets are 11.033505201339722s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0117 dataset--------------
# --------------The time it takes to process all datasets are 11.728797435760498s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0118 dataset--------------
# --------------The time it takes to process all datasets are 12.255440711975098s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0119 dataset--------------
# --------------The time it takes to process all datasets are 12.603053092956543s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0123 dataset--------------
# --------------The time it takes to process all datasets are 13.043155908584595s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0124 dataset--------------
# --------------The time it takes to process all datasets are 13.458119869232178s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0126 dataset--------------
# --------------The time it takes to process all datasets are 14.020287275314331s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0137 dataset--------------
# --------------The time it takes to process all datasets are 14.281243324279785s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0140 dataset--------------
# --------------The time it takes to process all datasets are 14.603176832199097s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0142 dataset--------------
# --------------The time it takes to process all datasets are 15.066604852676392s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0144 dataset--------------
# --------------The time it takes to process all datasets are 15.53401494026184s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0146 dataset--------------
# --------------The time it takes to process all datasets are 15.977689743041992s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0154 dataset--------------
# --------------The time it takes to process all datasets are 16.316380262374878s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0176 dataset--------------
# --------------The time it takes to process all datasets are 16.70081853866577s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0181 dataset--------------
# --------------The time it takes to process all datasets are 17.33348798751831s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0182 dataset--------------
# --------------The time it takes to process all datasets are 17.961522579193115s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0184 dataset--------------
# --------------The time it takes to process all datasets are 18.67180871963501s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0192 dataset--------------
# --------------The time it takes to process all datasets are 18.97135615348816s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0197 dataset--------------
# --------------The time it takes to process all datasets are 19.558802843093872s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0203 dataset--------------
# --------------The time it takes to process all datasets are 20.445067882537842s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0207 dataset--------------
# --------------The time it takes to process all datasets are 22.83308172225952s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0209 dataset--------------
# --------------The time it takes to process all datasets are 25.277109146118164s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0213 dataset--------------
# --------------The time it takes to process all datasets are 26.707685708999634s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0232 dataset--------------
# --------------The time it takes to process all datasets are 27.578753232955933s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0234 dataset--------------
# --------------The time it takes to process all datasets are 28.214405298233032s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0236 dataset--------------
# --------------The time it takes to process all datasets are 28.915945768356323s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0240 dataset--------------
# --------------The time it takes to process all datasets are 29.64042592048645s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0241 dataset--------------
# --------------The time it takes to process all datasets are 30.35690212249756s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0246 dataset--------------
# --------------The time it takes to process all datasets are 31.049996852874756s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0248 dataset--------------
# --------------The time it takes to process all datasets are 31.604938745498657s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0255 dataset--------------
# --------------The time it takes to process all datasets are 32.06702256202698s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0257 dataset--------------
# --------------The time it takes to process all datasets are 32.82680058479309s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0259 dataset--------------
# --------------The time it takes to process all datasets are 33.791528940200806s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0268 dataset--------------
# --------------The time it takes to process all datasets are 34.27612662315369s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0273 dataset--------------
# --------------The time it takes to process all datasets are 34.93967151641846s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0277 dataset--------------
# --------------The time it takes to process all datasets are 35.846827030181885s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0282 dataset--------------
# --------------The time it takes to process all datasets are 36.75212073326111s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0284 dataset--------------
# --------------The time it takes to process all datasets are 37.39247965812683s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0286 dataset--------------
# --------------The time it takes to process all datasets are 37.70778727531433s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0287 dataset--------------
# --------------The time it takes to process all datasets are 38.069685220718384s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0289 dataset--------------
# --------------The time it takes to process all datasets are 38.43337845802307s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0294 dataset--------------
# --------------The time it takes to process all datasets are 39.28591799736023s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0297 dataset--------------
# --------------The time it takes to process all datasets are 40.12417674064636s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0306 dataset--------------
# --------------The time it takes to process all datasets are 40.488598585128784s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0311 dataset--------------
# --------------The time it takes to process all datasets are 41.12084197998047s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0316 dataset--------------
# --------------The time it takes to process all datasets are 41.891555070877075s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0320 dataset--------------
# --------------The time it takes to process all datasets are 42.52125120162964s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0344 dataset--------------
# --------------The time it takes to process all datasets are 43.65863108634949s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0346 dataset--------------
# --------------The time it takes to process all datasets are 45.348581075668335s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0350 dataset--------------
# --------------The time it takes to process all datasets are 47.23699188232422s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0353 dataset--------------
# --------------The time it takes to process all datasets are 49.16319966316223s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0356 dataset--------------
# --------------The time it takes to process all datasets are 51.873140811920166s --------------
# --------------Start processing the L_2210_Suwon_A_A_C0359 dataset--------------
# --------------The time it takes to process all datasets are 54.067543029785156s --------------
# --------------Start processing the L_2210_Suwon_A_N_C0004 dataset--------------
# --------------The time it takes to process all datasets are 55.730790853500366s --------------
# --------------Start processing the L_2210_Suwon_A_N_C0017 dataset--------------
# --------------The time it takes to process all datasets are 57.442790031433105s --------------
# --------------Start processing the L_2210_Suwon_A_N_C0025 dataset--------------
# --------------The time it takes to process all datasets are 58.60709190368652s --------------
# --------------Start processing the L_2210_Suwon_A_N_C0031 dataset--------------
# --------------The time it takes to process all datasets are 59.313411235809326s --------------
# --------------Start processing the L_2210_Suwon_A_N_C0039 dataset--------------
# --------------The time it takes to process all datasets are 60.105618715286255s --------------
# --------------Start processing the L_2210_Suwon_A_N_C0044 dataset--------------
# --------------The time it takes to process all datasets are 60.385319232940674s --------------
# --------------Start processing the L_2210_Suwon_A_N_C0048 dataset--------------
# --------------The time it takes to process all datasets are 60.685500144958496s --------------
# --------------Start processing the L_2210_Suwon_A_N_C0058 dataset--------------
# --------------The time it takes to process all datasets are 61.2333402633667s --------------
# --------------Start processing the L_2210_Suwon_A_N_C0069 dataset--------------
# --------------The time it takes to process all datasets are 61.77317476272583s --------------
# --------------Start processing the L_2210_Suwon_A_N_C0070 dataset--------------
# --------------The time it takes to process all datasets are 62.247997760772705s --------------
# --------------Start processing the L_2210_Suwon_A_N_C0080 dataset--------------
# --------------The time it takes to process all datasets are 62.47038125991821s --------------
# --------------Start processing the L_2210_Suwon_A_N_C0086 dataset--------------
# --------------The time it takes to process all datasets are 62.941755056381226s --------------
# --------------Start processing the L_2210_Suwon_A_N_C0087 dataset--------------
# --------------The time it takes to process all datasets are 63.439074993133545s --------------
# --------------Start processing the L_2210_Suwon_A_N_C0090 dataset--------------
# --------------The time it takes to process all datasets are 63.900595903396606s --------------
# --------------Start processing the L_2210_Suwon_A_N_C0093 dataset--------------
# --------------The time it takes to process all datasets are 64.36328768730164s --------------
# --------------Start processing the L_2210_Suwon_A_N_C0106 dataset--------------
# --------------The time it takes to process all datasets are 64.80793786048889s --------------
# --------------Start processing the L_2210_Suwon_A_N_C0109 dataset--------------
# --------------The time it takes to process all datasets are 65.20594668388367s --------------
# --------------Start processing the L_2210_Suwon_A_N_C0114 dataset--------------
# --------------The time it takes to process all datasets are 65.4383647441864s --------------
# --------------Start processing the L_2210_Suwon_A_N_C0122 dataset--------------
# --------------The time it takes to process all datasets are 65.9113564491272s --------------
# --------------Start processing the L_2210_Suwon_A_N_C0125 dataset--------------
# --------------The time it takes to process all datasets are 66.4705262184143s --------------
# --------------Start processing the L_2210_Suwon_A_N_C0130 dataset--------------
# --------------The time it takes to process all datasets are 67.21241736412048s --------------
# --------------Start processing the L_2210_Suwon_A_N_C0133 dataset--------------
# --------------The time it takes to process all datasets are 67.50954747200012s --------------
# --------------Start processing the L_2210_Suwon_A_N_C0143 dataset--------------
# --------------The time it takes to process all datasets are 68.08365082740784s --------------
# --------------Start processing the L_2210_Suwon_A_N_C0149 dataset--------------
# --------------The time it takes to process all datasets are 68.44829249382019s --------------
# --------------Start processing the L_2210_Suwon_A_N_C0157 dataset--------------
# --------------The time it takes to process all datasets are 68.87794160842896s --------------
# --------------Start processing the L_2210_Suwon_A_N_C0161 dataset--------------
# --------------The time it takes to process all datasets are 69.39151978492737s --------------
# --------------Start processing the L_2210_Suwon_A_N_C0162 dataset--------------
# --------------The time it takes to process all datasets are 69.88673639297485s --------------
# --------------Start processing the L_2210_Suwon_A_N_C0182 dataset--------------
# --------------The time it takes to process all datasets are 71.27156925201416s --------------
# --------------Start processing the L_2210_Suwon_A_N_C0196 dataset--------------
# --------------The time it takes to process all datasets are 72.00549483299255s --------------
# --------------Start processing the L_2210_Suwon_A_N_C0199 dataset--------------
# --------------The time it takes to process all datasets are 72.67810225486755s --------------
# --------------Start processing the L_2210_Suwon_A_N_C0396 dataset--------------
# --------------The time it takes to process all datasets are 73.53838205337524s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0008 dataset--------------
# --------------The time it takes to process all datasets are 74.6719422340393s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0010 dataset--------------
# --------------The time it takes to process all datasets are 75.11960005760193s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0020 dataset--------------
# --------------The time it takes to process all datasets are 76.01065230369568s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0035 dataset--------------
# --------------The time it takes to process all datasets are 76.84117412567139s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0038 dataset--------------
# --------------The time it takes to process all datasets are 77.69922280311584s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0046 dataset--------------
# --------------The time it takes to process all datasets are 78.16559910774231s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0053 dataset--------------
# --------------The time it takes to process all datasets are 78.72680377960205s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0085 dataset--------------
# --------------The time it takes to process all datasets are 79.18413090705872s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0090 dataset--------------
# --------------The time it takes to process all datasets are 79.98044681549072s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0092 dataset--------------
# --------------The time it takes to process all datasets are 80.88028955459595s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0097 dataset--------------
# --------------The time it takes to process all datasets are 81.62940311431885s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0105 dataset--------------
# --------------The time it takes to process all datasets are 81.96112608909607s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0107 dataset--------------
# --------------The time it takes to process all datasets are 82.54297041893005s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0108 dataset--------------
# --------------The time it takes to process all datasets are 83.26612162590027s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0131 dataset--------------
# --------------The time it takes to process all datasets are 84.1444661617279s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0143 dataset--------------
# --------------The time it takes to process all datasets are 84.89719319343567s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0151 dataset--------------
# --------------The time it takes to process all datasets are 85.81138730049133s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0158 dataset--------------
# --------------The time it takes to process all datasets are 86.2455005645752s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0159 dataset--------------
# --------------The time it takes to process all datasets are 86.64804673194885s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0165 dataset--------------
# --------------The time it takes to process all datasets are 87.30437207221985s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0169 dataset--------------
# --------------The time it takes to process all datasets are 87.96856951713562s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0173 dataset--------------
# --------------The time it takes to process all datasets are 88.30854606628418s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0176 dataset--------------
# --------------The time it takes to process all datasets are 88.68653106689453s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0180 dataset--------------
# --------------The time it takes to process all datasets are 89.4288477897644s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0183 dataset--------------
# --------------The time it takes to process all datasets are 90.31669569015503s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0190 dataset--------------
# --------------The time it takes to process all datasets are 90.643319606781s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0195 dataset--------------
# --------------The time it takes to process all datasets are 91.10524225234985s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0196 dataset--------------
# --------------The time it takes to process all datasets are 91.63194704055786s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0197 dataset--------------
# --------------The time it takes to process all datasets are 92.24171137809753s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0200 dataset--------------
# --------------The time it takes to process all datasets are 93.61178398132324s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0205 dataset--------------
# --------------The time it takes to process all datasets are 94.85215449333191s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0206 dataset--------------
# --------------The time it takes to process all datasets are 96.14259576797485s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0208 dataset--------------
# --------------The time it takes to process all datasets are 97.8635368347168s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0209 dataset--------------
# --------------The time it takes to process all datasets are 99.32301425933838s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0213 dataset--------------
# --------------The time it takes to process all datasets are 100.06088662147522s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0216 dataset--------------
# --------------The time it takes to process all datasets are 100.79530048370361s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0221 dataset--------------
# --------------The time it takes to process all datasets are 101.7838237285614s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0247 dataset--------------
# --------------The time it takes to process all datasets are 102.93930578231812s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0248 dataset--------------
# --------------The time it takes to process all datasets are 103.82432866096497s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0250 dataset--------------
# --------------The time it takes to process all datasets are 104.36390542984009s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0256 dataset--------------
# --------------The time it takes to process all datasets are 105.03344964981079s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0266 dataset--------------
# --------------The time it takes to process all datasets are 105.64583921432495s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0269 dataset--------------
# --------------The time it takes to process all datasets are 106.13817739486694s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0277 dataset--------------
# --------------The time it takes to process all datasets are 106.81904578208923s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0281 dataset--------------
# --------------The time it takes to process all datasets are 107.48222756385803s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0282 dataset--------------
# --------------The time it takes to process all datasets are 107.9954206943512s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0288 dataset--------------
# --------------The time it takes to process all datasets are 108.42186331748962s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0297 dataset--------------
# --------------The time it takes to process all datasets are 109.1058554649353s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0299 dataset--------------
# --------------The time it takes to process all datasets are 109.79368185997009s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0303 dataset--------------
# --------------The time it takes to process all datasets are 110.39216589927673s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0304 dataset--------------
# --------------The time it takes to process all datasets are 110.82475543022156s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0306 dataset--------------
# --------------The time it takes to process all datasets are 111.34210658073425s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0308 dataset--------------
# --------------The time it takes to process all datasets are 111.76737189292908s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0310 dataset--------------
# --------------The time it takes to process all datasets are 112.27490520477295s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0318 dataset--------------
# --------------The time it takes to process all datasets are 112.73708486557007s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0319 dataset--------------
# --------------The time it takes to process all datasets are 113.20777940750122s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0320 dataset--------------
# --------------The time it takes to process all datasets are 113.70839595794678s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0322 dataset--------------
# --------------The time it takes to process all datasets are 113.99505877494812s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0323 dataset--------------
# --------------The time it takes to process all datasets are 114.25453686714172s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0338 dataset--------------
# --------------The time it takes to process all datasets are 114.86634135246277s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0342 dataset--------------
# --------------The time it takes to process all datasets are 115.49393939971924s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0352 dataset--------------
# --------------The time it takes to process all datasets are 116.206787109375s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0359 dataset--------------
# --------------The time it takes to process all datasets are 117.22483444213867s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0363 dataset--------------
# --------------The time it takes to process all datasets are 118.3340802192688s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0382 dataset--------------
# --------------The time it takes to process all datasets are 119.3089509010315s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0384 dataset--------------
# --------------The time it takes to process all datasets are 120.29869651794434s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0386 dataset--------------
# --------------The time it takes to process all datasets are 121.14295148849487s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0402 dataset--------------
# --------------The time it takes to process all datasets are 122.16408681869507s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0404 dataset--------------
# --------------The time it takes to process all datasets are 123.1745183467865s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0409 dataset--------------
# --------------The time it takes to process all datasets are 124.14848470687866s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0410 dataset--------------
# --------------The time it takes to process all datasets are 125.02936601638794s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0422 dataset--------------
# --------------The time it takes to process all datasets are 125.86275911331177s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0424 dataset--------------
# --------------The time it takes to process all datasets are 126.78961253166199s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0427 dataset--------------
# --------------The time it takes to process all datasets are 127.53836464881897s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0431 dataset--------------
# --------------The time it takes to process all datasets are 128.3840811252594s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0433 dataset--------------
# --------------The time it takes to process all datasets are 129.03637170791626s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0434 dataset--------------
# --------------The time it takes to process all datasets are 129.70538187026978s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0435 dataset--------------
# --------------The time it takes to process all datasets are 130.391357421875s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0436 dataset--------------
# --------------The time it takes to process all datasets are 131.09093165397644s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0437 dataset--------------
# --------------The time it takes to process all datasets are 131.69022297859192s --------------
# --------------Start processing the L_2210_Suwon_B_A_C0457 dataset--------------
# --------------The time it takes to process all datasets are 132.49172258377075s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0008 dataset--------------
# --------------The time it takes to process all datasets are 132.8651578426361s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0013 dataset--------------
# --------------The time it takes to process all datasets are 133.45638275146484s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0017 dataset--------------
# --------------The time it takes to process all datasets are 134.026921749115s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0021 dataset--------------
# --------------The time it takes to process all datasets are 134.53956627845764s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0032 dataset--------------
# --------------The time it takes to process all datasets are 135.01295471191406s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0037 dataset--------------
# --------------The time it takes to process all datasets are 135.48456978797913s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0042 dataset--------------
# --------------The time it takes to process all datasets are 135.9600532054901s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0047 dataset--------------
# --------------The time it takes to process all datasets are 136.25755739212036s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0048 dataset--------------
# --------------The time it takes to process all datasets are 136.52061128616333s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0050 dataset--------------
# --------------The time it takes to process all datasets are 136.89015126228333s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0056 dataset--------------
# --------------The time it takes to process all datasets are 137.62284231185913s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0070 dataset--------------
# --------------The time it takes to process all datasets are 138.12667083740234s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0078 dataset--------------
# --------------The time it takes to process all datasets are 138.60373377799988s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0089 dataset--------------
# --------------The time it takes to process all datasets are 139.11531352996826s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0091 dataset--------------
# --------------The time it takes to process all datasets are 139.7421531677246s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0098 dataset--------------
# --------------The time it takes to process all datasets are 140.0628046989441s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0100 dataset--------------
# --------------The time it takes to process all datasets are 140.48466277122498s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0103 dataset--------------
# --------------The time it takes to process all datasets are 140.9608554840088s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0108 dataset--------------
# --------------The time it takes to process all datasets are 141.5562686920166s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0111 dataset--------------
# --------------The time it takes to process all datasets are 142.11026763916016s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0115 dataset--------------
# --------------The time it takes to process all datasets are 142.37741994857788s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0131 dataset--------------
# --------------The time it takes to process all datasets are 142.88176465034485s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0133 dataset--------------
# --------------The time it takes to process all datasets are 143.2435028553009s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0134 dataset--------------
# --------------The time it takes to process all datasets are 143.58232474327087s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0150 dataset--------------
# --------------The time it takes to process all datasets are 143.8701012134552s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0165 dataset--------------
# --------------The time it takes to process all datasets are 144.3193678855896s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0170 dataset--------------
# --------------The time it takes to process all datasets are 144.6282992362976s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0172 dataset--------------
# --------------The time it takes to process all datasets are 144.9635031223297s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0177 dataset--------------
# --------------The time it takes to process all datasets are 145.3121325969696s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0178 dataset--------------
# --------------The time it takes to process all datasets are 145.60121703147888s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0195 dataset--------------
# --------------The time it takes to process all datasets are 145.93380093574524s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0197 dataset--------------
# --------------The time it takes to process all datasets are 146.23123931884766s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0213 dataset--------------
# --------------The time it takes to process all datasets are 146.63229632377625s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0215 dataset--------------
# --------------The time it takes to process all datasets are 147.04328107833862s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0222 dataset--------------
# --------------The time it takes to process all datasets are 147.30368947982788s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0226 dataset--------------
# --------------The time it takes to process all datasets are 147.79913067817688s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0228 dataset--------------
# --------------The time it takes to process all datasets are 148.18839502334595s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0233 dataset--------------
# --------------The time it takes to process all datasets are 148.60420966148376s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0234 dataset--------------
# --------------The time it takes to process all datasets are 148.90336656570435s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0242 dataset--------------
# --------------The time it takes to process all datasets are 149.14645648002625s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0246 dataset--------------
# --------------The time it takes to process all datasets are 149.4339714050293s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0258 dataset--------------
# --------------The time it takes to process all datasets are 149.69433116912842s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0261 dataset--------------
# --------------The time it takes to process all datasets are 150.0542869567871s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0265 dataset--------------
# --------------The time it takes to process all datasets are 150.52208709716797s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0274 dataset--------------
# --------------The time it takes to process all datasets are 150.89936113357544s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0281 dataset--------------
# --------------The time it takes to process all datasets are 151.34039211273193s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0285 dataset--------------
# --------------The time it takes to process all datasets are 151.8574378490448s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0288 dataset--------------
# --------------The time it takes to process all datasets are 152.35315465927124s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0311 dataset--------------
# --------------The time it takes to process all datasets are 152.7026469707489s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0313 dataset--------------
# --------------The time it takes to process all datasets are 153.1446509361267s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0317 dataset--------------
# --------------The time it takes to process all datasets are 153.51934027671814s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0319 dataset--------------
# --------------The time it takes to process all datasets are 153.99890661239624s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0320 dataset--------------
# --------------The time it takes to process all datasets are 154.41922450065613s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0327 dataset--------------
# --------------The time it takes to process all datasets are 154.62539792060852s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0338 dataset--------------
# --------------The time it takes to process all datasets are 155.14587831497192s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0343 dataset--------------
# --------------The time it takes to process all datasets are 155.44597864151s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0352 dataset--------------
# --------------The time it takes to process all datasets are 155.81923651695251s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0355 dataset--------------
# --------------The time it takes to process all datasets are 156.33767175674438s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0358 dataset--------------
# --------------The time it takes to process all datasets are 156.8059482574463s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0371 dataset--------------
# --------------The time it takes to process all datasets are 157.17600512504578s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0372 dataset--------------
# --------------The time it takes to process all datasets are 157.52995920181274s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0373 dataset--------------
# --------------The time it takes to process all datasets are 158.0423140525818s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0375 dataset--------------
# --------------The time it takes to process all datasets are 158.59440684318542s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0377 dataset--------------
# --------------The time it takes to process all datasets are 159.013201713562s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0381 dataset--------------
# --------------The time it takes to process all datasets are 159.31252145767212s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0383 dataset--------------
# --------------The time it takes to process all datasets are 159.5976870059967s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0388 dataset--------------
# --------------The time it takes to process all datasets are 159.92878484725952s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0390 dataset--------------
# --------------The time it takes to process all datasets are 160.29690623283386s --------------
# --------------Start processing the L_2210_Suwon_B_N_C0392 dataset--------------
# --------------The time it takes to process all datasets are 160.7582745552063s --------------
# --------------Start processing the L_2211_Pangyo_C_A_C0004 dataset--------------
# --------------The time it takes to process all datasets are 160.9231035709381s --------------
# --------------Start processing the L_2211_Pangyo_C_A_C0006 dataset--------------
# --------------The time it takes to process all datasets are 161.06030011177063s --------------
# --------------Start processing the L_2211_Pangyo_C_A_C0009 dataset--------------
# --------------The time it takes to process all datasets are 161.23238801956177s --------------
# --------------Start processing the L_2211_Pangyo_C_A_C0011 dataset--------------
# --------------The time it takes to process all datasets are 161.40165424346924s --------------
# --------------Start processing the L_2211_Pangyo_C_A_C0025 dataset--------------
# --------------The time it takes to process all datasets are 161.52682733535767s --------------
# --------------Start processing the L_2211_Pangyo_C_A_C0034 dataset--------------
# --------------The time it takes to process all datasets are 161.61180758476257s --------------
# --------------Start processing the L_2211_Pangyo_C_A_C0039 dataset--------------
# --------------The time it takes to process all datasets are 161.7432496547699s --------------
# --------------Start processing the L_2211_Pangyo_C_A_C0048 dataset--------------
# --------------The time it takes to process all datasets are 161.8468291759491s --------------
# --------------Start processing the L_2211_Pangyo_C_A_C0049 dataset--------------
# --------------The time it takes to process all datasets are 161.9696524143219s --------------
# --------------Start processing the L_2211_Pangyo_C_A_C0051 dataset--------------
# --------------The time it takes to process all datasets are 162.12720394134521s --------------
# --------------Start processing the L_2211_Pangyo_C_A_C0052 dataset--------------
# --------------The time it takes to process all datasets are 162.28324389457703s --------------
# --------------Start processing the L_2211_Pangyo_C_A_C0056 dataset--------------
# --------------The time it takes to process all datasets are 162.48277759552002s --------------
# --------------Start processing the L_2211_Pangyo_C_A_C0059 dataset--------------
# --------------The time it takes to process all datasets are 162.71284246444702s --------------
# --------------Start processing the L_2211_Pangyo_C_A_C0063 dataset--------------
# --------------The time it takes to process all datasets are 162.92614483833313s --------------
# --------------Start processing the L_2211_Pangyo_C_A_C0069 dataset--------------
# --------------The time it takes to process all datasets are 163.09499883651733s --------------
# --------------Start processing the L_2211_Pangyo_C_A_C0076 dataset--------------
# --------------The time it takes to process all datasets are 163.27352452278137s --------------
# --------------Start processing the L_2211_Pangyo_C_A_C0085 dataset--------------
# --------------The time it takes to process all datasets are 163.4352512359619s --------------
# ...
# --------------Start processing the L_2211_Suwon_B_F_C0272 dataset--------------
# --------------The time it takes to process all datasets are 316.60594415664673s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0289 dataset--------------
# --------------The time it takes to process all datasets are 317.01036643981934s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0310 dataset--------------
# --------------The time it takes to process all datasets are 317.60145926475525s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0313 dataset--------------
# --------------The time it takes to process all datasets are 318.2306089401245s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0320 dataset--------------
# --------------The time it takes to process all datasets are 318.8337404727936s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0323 dataset--------------
# --------------The time it takes to process all datasets are 319.3516528606415s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0324 dataset--------------
# --------------The time it takes to process all datasets are 319.7954578399658s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0329 dataset--------------
# --------------The time it takes to process all datasets are 320.569109916687s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0364 dataset--------------
# --------------The time it takes to process all datasets are 321.1191334724426s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0365 dataset--------------
# --------------The time it takes to process all datasets are 321.82153391838074s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0390 dataset--------------
# --------------The time it takes to process all datasets are 322.22055745124817s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0394 dataset--------------
# --------------The time it takes to process all datasets are 322.70263051986694s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0395 dataset--------------
# --------------The time it takes to process all datasets are 323.0864613056183s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0400 dataset--------------
# --------------The time it takes to process all datasets are 323.52133297920227s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0401 dataset--------------
# --------------The time it takes to process all datasets are 323.90937399864197s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0404 dataset--------------
# --------------The time it takes to process all datasets are 324.2584853172302s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0405 dataset--------------
# --------------The time it takes to process all datasets are 324.71991991996765s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0406 dataset--------------
# --------------The time it takes to process all datasets are 325.13793897628784s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0408 dataset--------------
# --------------The time it takes to process all datasets are 325.42303943634033s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0435 dataset--------------
# --------------The time it takes to process all datasets are 325.83256912231445s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0436 dataset--------------
# --------------The time it takes to process all datasets are 326.27062821388245s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0437 dataset--------------
# --------------The time it takes to process all datasets are 326.715443611145s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0440 dataset--------------
# --------------The time it takes to process all datasets are 327.2024064064026s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0441 dataset--------------
# --------------The time it takes to process all datasets are 327.8131546974182s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0442 dataset--------------
# --------------The time it takes to process all datasets are 328.400102853775s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0483 dataset--------------
# --------------The time it takes to process all datasets are 328.8575439453125s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0491 dataset--------------
# --------------The time it takes to process all datasets are 329.5020079612732s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0493 dataset--------------
# --------------The time it takes to process all datasets are 330.12469458580017s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0516 dataset--------------
# --------------The time it takes to process all datasets are 330.48075318336487s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0517 dataset--------------
# --------------The time it takes to process all datasets are 330.89931297302246s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0518 dataset--------------
# --------------The time it takes to process all datasets are 331.3536069393158s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0519 dataset--------------
# --------------The time it takes to process all datasets are 331.71213722229004s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0524 dataset--------------
# --------------The time it takes to process all datasets are 332.1057903766632s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0526 dataset--------------
# --------------The time it takes to process all datasets are 332.5562033653259s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0528 dataset--------------
# --------------The time it takes to process all datasets are 333.06753945350647s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0532 dataset--------------
# --------------The time it takes to process all datasets are 333.4665243625641s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0533 dataset--------------
# --------------The time it takes to process all datasets are 333.73715019226074s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0535 dataset--------------
# --------------The time it takes to process all datasets are 334.06386160850525s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0536 dataset--------------
# --------------The time it takes to process all datasets are 334.3837616443634s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0541 dataset--------------
# --------------The time it takes to process all datasets are 334.6705582141876s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0543 dataset--------------
# --------------The time it takes to process all datasets are 335.00463247299194s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0554 dataset--------------
# --------------The time it takes to process all datasets are 335.401154756546s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0573 dataset--------------
# --------------The time it takes to process all datasets are 335.8990728855133s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0582 dataset--------------
# --------------The time it takes to process all datasets are 336.6211807727814s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0591 dataset--------------
# --------------The time it takes to process all datasets are 337.1902017593384s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0600 dataset--------------
# --------------The time it takes to process all datasets are 337.9490909576416s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0608 dataset--------------
# --------------The time it takes to process all datasets are 338.6225688457489s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0625 dataset--------------
# --------------The time it takes to process all datasets are 339.25155901908875s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0637 dataset--------------
# --------------The time it takes to process all datasets are 339.9328598976135s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0653 dataset--------------
# --------------The time it takes to process all datasets are 340.71694135665894s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0655 dataset--------------
# --------------The time it takes to process all datasets are 341.3416566848755s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0658 dataset--------------
# --------------The time it takes to process all datasets are 341.82852816581726s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0663 dataset--------------
# --------------The time it takes to process all datasets are 342.29061341285706s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0670 dataset--------------
# --------------The time it takes to process all datasets are 342.9730591773987s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0680 dataset--------------
# --------------The time it takes to process all datasets are 343.62591004371643s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0682 dataset--------------
# --------------The time it takes to process all datasets are 344.2805292606354s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0720 dataset--------------
# --------------The time it takes to process all datasets are 344.8626275062561s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0722 dataset--------------
# --------------The time it takes to process all datasets are 345.39646005630493s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0728 dataset--------------
# --------------The time it takes to process all datasets are 346.0807321071625s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0732 dataset--------------
# --------------The time it takes to process all datasets are 346.5822379589081s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0741 dataset--------------
# --------------The time it takes to process all datasets are 347.1250956058502s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0774 dataset--------------
# --------------The time it takes to process all datasets are 347.83875942230225s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0780 dataset--------------
# --------------The time it takes to process all datasets are 348.6226282119751s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0794 dataset--------------
# --------------The time it takes to process all datasets are 349.0923364162445s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0796 dataset--------------
# --------------The time it takes to process all datasets are 349.67418813705444s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0801 dataset--------------
# --------------The time it takes to process all datasets are 350.3002498149872s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0810 dataset--------------
# --------------The time it takes to process all datasets are 350.9080719947815s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0817 dataset--------------
# --------------The time it takes to process all datasets are 351.4649147987366s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0821 dataset--------------
# --------------The time it takes to process all datasets are 351.9138219356537s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0838 dataset--------------
# --------------The time it takes to process all datasets are 352.44155859947205s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0844 dataset--------------
# --------------The time it takes to process all datasets are 352.9277272224426s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0845 dataset--------------
# --------------The time it takes to process all datasets are 353.3695569038391s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0846 dataset--------------
# --------------The time it takes to process all datasets are 353.7567422389984s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0852 dataset--------------
# --------------The time it takes to process all datasets are 354.29238653182983s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0861 dataset--------------
# --------------The time it takes to process all datasets are 354.70111060142517s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0876 dataset--------------
# --------------The time it takes to process all datasets are 355.24574089050293s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0878 dataset--------------
# --------------The time it takes to process all datasets are 355.5577163696289s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0879 dataset--------------
# --------------The time it takes to process all datasets are 355.91863107681274s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0888 dataset--------------
# --------------The time it takes to process all datasets are 356.42473578453064s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0894 dataset--------------
# --------------The time it takes to process all datasets are 356.9277358055115s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0925 dataset--------------
# --------------The time it takes to process all datasets are 357.32714080810547s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0930 dataset--------------
# --------------The time it takes to process all datasets are 357.89880895614624s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0931 dataset--------------
# --------------The time it takes to process all datasets are 358.46448588371277s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0941 dataset--------------
# --------------The time it takes to process all datasets are 359.2293486595154s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0964 dataset--------------
# --------------The time it takes to process all datasets are 359.767706155777s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0966 dataset--------------
# --------------The time it takes to process all datasets are 360.23737621307373s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0991 dataset--------------
# --------------The time it takes to process all datasets are 360.77824425697327s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0992 dataset--------------
# --------------The time it takes to process all datasets are 361.21688079833984s --------------
# --------------Start processing the L_2211_Suwon_B_F_C0995 dataset--------------
# --------------The time it takes to process all datasets are 361.74451971054077s --------------
# --------------Start processing the L_2211_Suwon_B_F_C1000 dataset--------------
# --------------The time it takes to process all datasets are 362.1196343898773s --------------
# --------------Start processing the L_2211_Suwon_B_F_C1001 dataset--------------
# --------------The time it takes to process all datasets are 362.42309737205505s --------------
# --------------FPS = 18.514272541277002 --------------

# %%
# %cd /NIA50/50-2/models/DeepFusionMOT

# !python main.py --help
# Out:
# /NIA50/50-2/models/DeepFusionMOT
# usage: main.py [-h] [--data-root DATA_ROOT] [--detections3D DETECTIONS3D]
#                [--detections2D DETECTIONS2D] [--save-root SAVE_ROOT]
#                [--save-img]
#
# options:
#   -h, --help            show this help message and exit
#   --data-root DATA_ROOT
#                         dataset path
#   --detections3D DETECTIONS3D
#                         detections 3D foldername
#   --detections2D DETECTIONS2D
#                         detections 2D foldername
#   --save-root SAVE_ROOT
#                         result save path
#   --save-img            save image

# %% [markdown]
# # # 결과물 영상화
# ---

# %%
# 디텍팅 결과 영상 생성
# img_to_video.py 수정 필수

# %cd /content/drive/MyDrive/workspace/study/3D_Object_detection/DeepFusionMOT/visualization
# !python img_to_video.py
